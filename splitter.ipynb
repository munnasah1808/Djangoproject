# %%
import json
import pandas as pd
from pathlib import Path
from collections.abc import MutableMapping

def flatten_json(nested_json, parent_key='', sep='_'):
    """Recursively flattens nested JSON."""
    items = []
    if isinstance(nested_json, MutableMapping):
        for k, v in nested_json.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(flatten_json(v, new_key, sep=sep).items())
    elif isinstance(nested_json, list):
        for idx, item in enumerate(nested_json):
            items.extend(flatten_json(item, f"{parent_key}{sep}{idx}", sep=sep).items())
    else:
        items.append((parent_key, nested_json))
    return dict(items)

def normalize_dlt_data(jsonl_file_path):
    normalized_records = []

    with open(jsonl_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            record = json.loads(line)
            flattened_record = flatten_json(record)
            normalized_records.append(flattened_record)

    df = pd.DataFrame(normalized_records)
    return df

jsonl_file_path = Path(r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl")


df = normalize_dlt_data(jsonl_file_path)

# View the first few rows
print(df.head())

# Save to Excel or CSV if needed
df.to_csv('normalized_output.csv', index=False)
# Out:
#   articles_0_ArticleId articles_0_Position  articles_0_Quantity  \
# 0           9839261880                   2               3240.0
# 1           9824896480                   2                 48.0
# 2           9845215780                   1                240.0
# 3           9818362280                   2              24000.0
# 4           9859518980                   4                 12.0
#
#    articles_0_Weight articles_1_ArticleId articles_1_Position  \
# 0              700.0           9839257180                   1
# 1             7100.0           9824896480                   1
# 2            32500.0                  NaN                 NaN
# 3                7.0           9818361480                   1
# 4                0.0           9859518980                   5
#
#    articles_1_Quantity  articles_1_Weight basics_CommunicatedDate  \
# 0               3240.0              654.0    2025-03-06T10:11:25Z
# 1                 48.0             7100.0    2025-03-06T10:11:25Z
# 2                  NaN                NaN    2025-03-06T10:11:25Z
# 3              36000.0               13.0    2025-03-06T10:11:25Z
# 4                 12.0                0.0    2025-03-06T10:11:25Z
#
#   basics_ConsignorLocationKey  ... handling_units_294_Stackability  \
# 0                  A0023B  02  ...                             NaN
# 1                  31204S  01  ...                             NaN
# 2                  22342J  04  ...                             NaN
# 3                  13736E  65  ...                             NaN
# 4                  99778D  01  ...                             NaN
#
#   handling_units_295_Dimension_Length handling_units_295_Dimension_Height  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   handling_units_295_Dimension_Width handling_units_295_GrossWeight  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   handling_units_295_HandlingUnitId handling_units_295_HandlingUnitPosition  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
#
#   handling_units_295_HandlingUnitPositionLevel2 handling_units_295_Quantity  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           NaN                         NaN
#
#   handling_units_295_Stackability
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 3329 columns]

# %%
import json
import os
from collections.abc import MutableMapping

# Function to recursively flatten nested JSON
def flatten_json(nested_json, parent_key='', sep='_'):
    """Recursively flattens nested JSON object into a flat dictionary."""
    items = []
    if isinstance(nested_json, MutableMapping):
        for k, v in nested_json.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(flatten_json(v, new_key, sep=sep).items())
    elif isinstance(nested_json, list):
        # For lists, handle each item individually and store as separate flattened object
        for idx, item in enumerate(nested_json):
            items.extend(flatten_json(item, f"{parent_key}{sep}{idx}", sep=sep).items())
    else:
        items.append((parent_key, nested_json))
    return dict(items)

# Function to split nested data into multiple flat JSON files
def process_and_split_jsonl(input_jsonl_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        count = 0

        for line in file:
            count += 1
            record = json.loads(line)

            # Flatten the top-level record
            main_record = {}
            nested_records = {}

            for key, value in record.items():
                if isinstance(value, list):
                    # Handle nested lists (like articles or handling_units) separately
                    nested_records[key] = value
                elif isinstance(value, dict):
                    # Flatten nested dicts directly into the main record
                    flat_part = flatten_json(value, key)
                    main_record.update(flat_part)
                else:
                    main_record[key] = value

            # Write the main flat record
            main_file = os.path.join(output_folder, f'record_{count}_main.json')
            with open(main_file, 'w', encoding='utf-8') as f:
                json.dump(main_record, f, indent=4)

            # Write each nested list into separate files
            for nested_key, nested_list in nested_records.items():
                nested_file = os.path.join(output_folder, f'record_{count}_{nested_key}.json')
                with open(nested_file, 'w', encoding='utf-8') as f:
                    flattened_list = [flatten_json(item) for item in nested_list]
                    json.dump(flattened_list, f, indent=4)

            print(f"Processed and saved record {count}")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl"  # Update with your actual path
    output_folder = r"C:\Users\munna\Downloads\flattened_output"

    process_and_split_jsonl(input_jsonl_path, output_folder)

    print(f"All flattened data saved to '{output_folder}' folder.")
# Out:
# Processed and saved record 1
# Processed and saved record 2
# Processed and saved record 3
# Processed and saved record 4
# Processed and saved record 5
# Processed and saved record 6
# Processed and saved record 7
# Processed and saved record 8
# Processed and saved record 9
# Processed and saved record 10
# Processed and saved record 11
# Processed and saved record 12
# Processed and saved record 13
# Processed and saved record 14
# Processed and saved record 15
# Processed and saved record 16
# Processed and saved record 17
# Processed and saved record 18
# Processed and saved record 19
# Processed and saved record 20
# Processed and saved record 21
# Processed and saved record 22
# Processed and saved record 23
# Processed and saved record 24
# Processed and saved record 25
# Processed and saved record 26
# Processed and saved record 27
# Processed and saved record 28
# Processed and saved record 29
# Processed and saved record 30
# Processed and saved record 31
# Processed and saved record 32
# Processed and saved record 33
# Processed and saved record 34
# Processed and saved record 35
# Processed and saved record 36
# Processed and saved record 37
# Processed and saved record 38
# Processed and saved record 39
# Processed and saved record 40
# Processed and saved record 41
# Processed and saved record 42
# Processed and saved record 43
# Processed and saved record 44
# Processed and saved record 45
# Processed and saved record 46
# Processed and saved record 47
# Processed and saved record 48
# Processed and saved record 49
# Processed and saved record 50
# Processed and saved record 51
# Processed and saved record 52
# Processed and saved record 53
# Processed and saved record 54
# Processed and saved record 55
# Processed and saved record 56
# Processed and saved record 57
# Processed and saved record 58
# Processed and saved record 59
# Processed and saved record 60
# Processed and saved record 61
# Processed and saved record 62
# Processed and saved record 63
# Processed and saved record 64
# Processed and saved record 65
# Processed and saved record 66
# Processed and saved record 67
# Processed and saved record 68
# Processed and saved record 69
# Processed and saved record 70
# Processed and saved record 71
# Processed and saved record 72
# Processed and saved record 73
# Processed and saved record 74
# Processed and saved record 75
# Processed and saved record 76
# Processed and saved record 77
# Processed and saved record 78
# Processed and saved record 79
# Processed and saved record 80
# Processed and saved record 81
# Processed and saved record 82
# Processed and saved record 83
# Processed and saved record 84
# Processed and saved record 85
# Processed and saved record 86
# Processed and saved record 87
# Processed and saved record 88
# Processed and saved record 89
# Processed and saved record 90
# Processed and saved record 91
# Processed and saved record 92
# Processed and saved record 93
# Processed and saved record 94
# Processed and saved record 95
# Processed and saved record 96
# Processed and saved record 97
# Processed and saved record 98
# Processed and saved record 99
# Processed and saved record 100
# Processed and saved record 101
# Processed and saved record 102
# Processed and saved record 103
# Processed and saved record 104
# Processed and saved record 105
# Processed and saved record 106
# Processed and saved record 107
# Processed and saved record 108
# Processed and saved record 109
# Processed and saved record 110
# Processed and saved record 111
# Processed and saved record 112
# Processed and saved record 113
# Processed and saved record 114
# Processed and saved record 115
# Processed and saved record 116
# Processed and saved record 117
# Processed and saved record 118
# Processed and saved record 119
# Processed and saved record 120
# Processed and saved record 121
# Processed and saved record 122
# Processed and saved record 123
# Processed and saved record 124
# Processed and saved record 125
# Processed and saved record 126
# Processed and saved record 127
# Processed and saved record 128
# Processed and saved record 129
# Processed and saved record 130
# Processed and saved record 131
# Processed and saved record 132
# Processed and saved record 133
# Processed and saved record 134
# Processed and saved record 135
# Processed and saved record 136
# Processed and saved record 137
# Processed and saved record 138
# Processed and saved record 139
# Processed and saved record 140
# Processed and saved record 141
# Processed and saved record 142
# Processed and saved record 143
# Processed and saved record 144
# Processed and saved record 145
# Processed and saved record 146
# Processed and saved record 147
# Processed and saved record 148
# Processed and saved record 149
# Processed and saved record 150
# Processed and saved record 151
# Processed and saved record 152
# Processed and saved record 153
# Processed and saved record 154
# Processed and saved record 155
# Processed and saved record 156
# Processed and saved record 157
# Processed and saved record 158
# Processed and saved record 159
# Processed and saved record 160
# Processed and saved record 161
# Processed and saved record 162
# Processed and saved record 163
# Processed and saved record 164
# Processed and saved record 165
# Processed and saved record 166
# Processed and saved record 167
# Processed and saved record 168
# Processed and saved record 169
# Processed and saved record 170
# Processed and saved record 171
# Processed and saved record 172
# Processed and saved record 173
# Processed and saved record 174
# Processed and saved record 175
# Processed and saved record 176
# Processed and saved record 177
# Processed and saved record 178
# Processed and saved record 179
# Processed and saved record 180
# Processed and saved record 181
# Processed and saved record 182
# Processed and saved record 183
# Processed and saved record 184
# Processed and saved record 185
# Processed and saved record 186
# Processed and saved record 187
# Processed and saved record 188
# Processed and saved record 189
# Processed and saved record 190
# Processed and saved record 191
# Processed and saved record 192
# Processed and saved record 193
# Processed and saved record 194
# Processed and saved record 195
# Processed and saved record 196
# Processed and saved record 197
# Processed and saved record 198
# Processed and saved record 199
# Processed and saved record 200
# Processed and saved record 201
# Processed and saved record 202
# Processed and saved record 203
# Processed and saved record 204
# Processed and saved record 205
# Processed and saved record 206
# Processed and saved record 207
# Processed and saved record 208
# Processed and saved record 209
# Processed and saved record 210
# Processed and saved record 211
# Processed and saved record 212
# Processed and saved record 213
# Processed and saved record 214
# Processed and saved record 215
# Processed and saved record 216
# Processed and saved record 217
# Processed and saved record 218
# Processed and saved record 219
# Processed and saved record 220
# Processed and saved record 221
# Processed and saved record 222
# Processed and saved record 223
# Processed and saved record 224
# Processed and saved record 225
# Processed and saved record 226
# Processed and saved record 227
# Processed and saved record 228
# Processed and saved record 229
# Processed and saved record 230
# Processed and saved record 231
# Processed and saved record 232
# Processed and saved record 233
# Processed and saved record 234
# Processed and saved record 235
# Processed and saved record 236
# Processed and saved record 237
# Processed and saved record 238
# Processed and saved record 239
# Processed and saved record 240
# Processed and saved record 241
# Processed and saved record 242
# Processed and saved record 243
# Processed and saved record 244
# Processed and saved record 245
# Processed and saved record 246
# Processed and saved record 247
# Processed and saved record 248
# Processed and saved record 249
# Processed and saved record 250
# Processed and saved record 251
# Processed and saved record 252
# Processed and saved record 253
# Processed and saved record 254
# Processed and saved record 255
# Processed and saved record 256
# Processed and saved record 257
# Processed and saved record 258
# Processed and saved record 259
# Processed and saved record 260
# Processed and saved record 261
# Processed and saved record 262
# Processed and saved record 263
# Processed and saved record 264
# Processed and saved record 265
# Processed and saved record 266
# Processed and saved record 267
# Processed and saved record 268
# Processed and saved record 269
# Processed and saved record 270
# Processed and saved record 271
# Processed and saved record 272
# Processed and saved record 273
# Processed and saved record 274
# Processed and saved record 275
# Processed and saved record 276
# Processed and saved record 277
# Processed and saved record 278
# Processed and saved record 279
# Processed and saved record 280
# Processed and saved record 281
# Processed and saved record 282
# Processed and saved record 283
# Processed and saved record 284
# Processed and saved record 285
# Processed and saved record 286
# Processed and saved record 287
# Processed and saved record 288
# Processed and saved record 289
# Processed and saved record 290
# Processed and saved record 291
# Processed and saved record 292
# Processed and saved record 293
# Processed and saved record 294
# Processed and saved record 295
# Processed and saved record 296
# Processed and saved record 297
# Processed and saved record 298
# Processed and saved record 299
# Processed and saved record 300
# Processed and saved record 301
# Processed and saved record 302
# Processed and saved record 303
# Processed and saved record 304
# Processed and saved record 305
# Processed and saved record 306
# Processed and saved record 307
# Processed and saved record 308
# Processed and saved record 309
# Processed and saved record 310
# Processed and saved record 311
# Processed and saved record 312
# Processed and saved record 313
# Processed and saved record 314
# Processed and saved record 315
# Processed and saved record 316
# Processed and saved record 317
# Processed and saved record 318
# Processed and saved record 319
# Processed and saved record 320
# Processed and saved record 321
# Processed and saved record 322
# Processed and saved record 323
# Processed and saved record 324
# Processed and saved record 325
# Processed and saved record 326
# Processed and saved record 327
# Processed and saved record 328
# Processed and saved record 329
# Processed and saved record 330
# Processed and saved record 331
# Processed and saved record 332
# Processed and saved record 333
# Processed and saved record 334
# Processed and saved record 335
# Processed and saved record 336
# Processed and saved record 337
# Processed and saved record 338
# Processed and saved record 339
# Processed and saved record 340
# Processed and saved record 341
# Processed and saved record 342
# Processed and saved record 343
# Processed and saved record 344
# Processed and saved record 345
# Processed and saved record 346
# Processed and saved record 347
# Processed and saved record 348
# Processed and saved record 349
# Processed and saved record 350
# Processed and saved record 351
# Processed and saved record 352
# Processed and saved record 353
# Processed and saved record 354
# Processed and saved record 355
# Processed and saved record 356
# Processed and saved record 357
# Processed and saved record 358
# Processed and saved record 359
# Processed and saved record 360
# Processed and saved record 361
# Processed and saved record 362
# Processed and saved record 363
# Processed and saved record 364
# Processed and saved record 365
# Processed and saved record 366
# Processed and saved record 367
# Processed and saved record 368
# Processed and saved record 369
# Processed and saved record 370
# Processed and saved record 371
# Processed and saved record 372
# Processed and saved record 373
# Processed and saved record 374
# Processed and saved record 375
# Processed and saved record 376
# Processed and saved record 377
# Processed and saved record 378
# Processed and saved record 379
# Processed and saved record 380
# Processed and saved record 381
# Processed and saved record 382
# Processed and saved record 383
# Processed and saved record 384
# Processed and saved record 385
# Processed and saved record 386
# Processed and saved record 387
# Processed and saved record 388
# Processed and saved record 389
# Processed and saved record 390
# Processed and saved record 391
# Processed and saved record 392
# Processed and saved record 393
# Processed and saved record 394
# Processed and saved record 395
# Processed and saved record 396
# Processed and saved record 397
# Processed and saved record 398
# Processed and saved record 399
# Processed and saved record 400
# Processed and saved record 401
# Processed and saved record 402
# Processed and saved record 403
# Processed and saved record 404
# Processed and saved record 405
# Processed and saved record 406
# Processed and saved record 407
# Processed and saved record 408
# Processed and saved record 409
# Processed and saved record 410
# Processed and saved record 411
# Processed and saved record 412
# Processed and saved record 413
# Processed and saved record 414
# Processed and saved record 415
# Processed and saved record 416
# Processed and saved record 417
# Processed and saved record 418
# Processed and saved record 419
# Processed and saved record 420
# Processed and saved record 421
# Processed and saved record 422
# Processed and saved record 423
# Processed and saved record 424
# Processed and saved record 425
# Processed and saved record 426
# Processed and saved record 427
# Processed and saved record 428
# Processed and saved record 429
# Processed and saved record 430
# Processed and saved record 431
# Processed and saved record 432
# Processed and saved record 433
# Processed and saved record 434
# Processed and saved record 435
# Processed and saved record 436
# Processed and saved record 437
# Processed and saved record 438
# Processed and saved record 439
# Processed and saved record 440
# Processed and saved record 441
# Processed and saved record 442
# Processed and saved record 443
# Processed and saved record 444
# Processed and saved record 445
# Processed and saved record 446
# Processed and saved record 447
# Processed and saved record 448
# Processed and saved record 449
# Processed and saved record 450
# Processed and saved record 451
# Processed and saved record 452
# Processed and saved record 453
# Processed and saved record 454
# Processed and saved record 455
# Processed and saved record 456
# Processed and saved record 457
# Processed and saved record 458
# Processed and saved record 459
# Processed and saved record 460
# Processed and saved record 461
# Processed and saved record 462
# Processed and saved record 463
# Processed and saved record 464
# Processed and saved record 465
# Processed and saved record 466
# Processed and saved record 467
# Processed and saved record 468
# Processed and saved record 469
# Processed and saved record 470
# Processed and saved record 471
# Processed and saved record 472
# Processed and saved record 473
# Processed and saved record 474
# Processed and saved record 475
# Processed and saved record 476
# Processed and saved record 477
# Processed and saved record 478
# Processed and saved record 479
# Processed and saved record 480
# Processed and saved record 481
# Processed and saved record 482
# Processed and saved record 483
# Processed and saved record 484
# Processed and saved record 485
# Processed and saved record 486
# Processed and saved record 487
# Processed and saved record 488
# Processed and saved record 489
# Processed and saved record 490
# Processed and saved record 491
# Processed and saved record 492
# Processed and saved record 493
# Processed and saved record 494
# Processed and saved record 495
# Processed and saved record 496
# Processed and saved record 497
# Processed and saved record 498
# Processed and saved record 499
# Processed and saved record 500
# Processed and saved record 501
# Processed and saved record 502
# Processed and saved record 503
# Processed and saved record 504
# Processed and saved record 505
# Processed and saved record 506
# Processed and saved record 507
# Processed and saved record 508
# Processed and saved record 509
# Processed and saved record 510
# Processed and saved record 511
# Processed and saved record 512
# Processed and saved record 513
# Processed and saved record 514
# Processed and saved record 515
# Processed and saved record 516
# Processed and saved record 517
# Processed and saved record 518
# Processed and saved record 519
# Processed and saved record 520
# Processed and saved record 521
# Processed and saved record 522
# Processed and saved record 523
# Processed and saved record 524
# Processed and saved record 525
# Processed and saved record 526
# Processed and saved record 527
# Processed and saved record 528
# Processed and saved record 529
# Processed and saved record 530
# Processed and saved record 531
# Processed and saved record 532
# Processed and saved record 533
# Processed and saved record 534
# Processed and saved record 535
# Processed and saved record 536
# Processed and saved record 537
# Processed and saved record 538
# Processed and saved record 539
# Processed and saved record 540
# Processed and saved record 541
# Processed and saved record 542
# Processed and saved record 543
# Processed and saved record 544
# Processed and saved record 545
# Processed and saved record 546
# Processed and saved record 547
# Processed and saved record 548
# Processed and saved record 549
# Processed and saved record 550
# Processed and saved record 551
# Processed and saved record 552
# Processed and saved record 553
# Processed and saved record 554
# Processed and saved record 555
# Processed and saved record 556
# Processed and saved record 557
# Processed and saved record 558
# Processed and saved record 559
# Processed and saved record 560
# Processed and saved record 561
# Processed and saved record 562
# Processed and saved record 563
# Processed and saved record 564
# Processed and saved record 565
# Processed and saved record 566
# Processed and saved record 567
# Processed and saved record 568
# Processed and saved record 569
# Processed and saved record 570
# Processed and saved record 571
# Processed and saved record 572
# Processed and saved record 573
# Processed and saved record 574
# Processed and saved record 575
# Processed and saved record 576
# Processed and saved record 577
# Processed and saved record 578
# Processed and saved record 579
# Processed and saved record 580
# Processed and saved record 581
# Processed and saved record 582
# Processed and saved record 583
# Processed and saved record 584
# Processed and saved record 585
# Processed and saved record 586
# Processed and saved record 587
# Processed and saved record 588
# Processed and saved record 589
# Processed and saved record 590
# Processed and saved record 591
# Processed and saved record 592
# Processed and saved record 593
# Processed and saved record 594
# Processed and saved record 595
# Processed and saved record 596
# Processed and saved record 597
# Processed and saved record 598
# Processed and saved record 599
# Processed and saved record 600
# Processed and saved record 601
# Processed and saved record 602
# Processed and saved record 603
# Processed and saved record 604
# Processed and saved record 605
# Processed and saved record 606
# Processed and saved record 607
# Processed and saved record 608
# Processed and saved record 609
# Processed and saved record 610
# Processed and saved record 611
# Processed and saved record 612
# Processed and saved record 613
# Processed and saved record 614
# Processed and saved record 615
# Processed and saved record 616
# Processed and saved record 617
# Processed and saved record 618
# Processed and saved record 619
# Processed and saved record 620
# Processed and saved record 621
# Processed and saved record 622
# Processed and saved record 623
# Processed and saved record 624
# Processed and saved record 625
# Processed and saved record 626
# Processed and saved record 627
# Processed and saved record 628
# Processed and saved record 629
# Processed and saved record 630
# Processed and saved record 631
# Processed and saved record 632
# Processed and saved record 633
# Processed and saved record 634
# Processed and saved record 635
# Processed and saved record 636
# Processed and saved record 637
# Processed and saved record 638
# Processed and saved record 639
# Processed and saved record 640
# Processed and saved record 641
# Processed and saved record 642
# Processed and saved record 643
# Processed and saved record 644
# Processed and saved record 645
# Processed and saved record 646
# Processed and saved record 647
# Processed and saved record 648
# Processed and saved record 649
# Processed and saved record 650
# Processed and saved record 651
# Processed and saved record 652
# Processed and saved record 653
# Processed and saved record 654
# Processed and saved record 655
# Processed and saved record 656
# Processed and saved record 657
# Processed and saved record 658
# Processed and saved record 659
# Processed and saved record 660
# Processed and saved record 661
# Processed and saved record 662
# Processed and saved record 663
# Processed and saved record 664
# Processed and saved record 665
# Processed and saved record 666
# Processed and saved record 667
# Processed and saved record 668
# Processed and saved record 669
# Processed and saved record 670
# Processed and saved record 671
# Processed and saved record 672
# Processed and saved record 673
# Processed and saved record 674
# Processed and saved record 675
# Processed and saved record 676
# Processed and saved record 677
# Processed and saved record 678
# Processed and saved record 679
# Processed and saved record 680
# Processed and saved record 681
# Processed and saved record 682
# Processed and saved record 683
# Processed and saved record 684
# Processed and saved record 685
# Processed and saved record 686
# Processed and saved record 687
# Processed and saved record 688
# All flattened data saved to 'C:\Users\munna\Downloads\flattened_output' folder.

# %%
import json
import os

def process_jsonl_to_parent_child(input_jsonl_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        count = 0

        for line in file:
            count += 1
            record = json.loads(line)

            parent_data = {}
            child_data = {}

            # Split parent (simple fields) and child (nested lists)
            for key, value in record.items():
                if isinstance(value, list):
                    # Nested lists go into the child file
                    child_data[key] = value
                else:
                    # Simple fields go into the parent file
                    parent_data[key] = value

            # Save parent JSON (top-level fields only)
            parent_file = os.path.join(output_folder, f'record_{count}_parent.json')
            with open(parent_file, 'w', encoding='utf-8') as parent_out:
                json.dump(parent_data, parent_out, indent=4)

            # Save child JSON (only nested lists)
            child_file = os.path.join(output_folder, f'record_{count}_child.json')
            with open(child_file, 'w', encoding='utf-8') as child_out:
                json.dump(child_data, child_out, indent=4)

            print(f"Saved: {parent_file}, {child_file}")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl"  # Adjust to your file path
    output_folder = r"C:\Users\munna\Downloads\parent_child_output"

    process_jsonl_to_parent_child(input_jsonl_path, output_folder)

    print(f"Processing complete. Files saved in '{output_folder}'.")
# Out:
# Saved: C:\Users\munna\Downloads\parent_child_output\record_1_parent.json, C:\Users\munna\Downloads\parent_child_output\record_1_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record_2_parent.json, C:\Users\munna\Downloads\parent_child_output\record_2_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record_3_parent.json, C:\Users\munna\Downloads\parent_child_output\record_3_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record_4_parent.json, C:\Users\munna\Downloads\parent_child_output\record_4_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record_5_parent.json, C:\Users\munna\Downloads\parent_child_output\record_5_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record_6_parent.json, C:\Users\munna\Downloads\parent_child_output\record_6_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record_7_parent.json, C:\Users\munna\Downloads\parent_child_output\record_7_child.json
# Saved: C:\Users\munna\Downloads\parent_child_output\record
path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        count = 0

        for line in file:
            count += 1
            record = json.loads(line)

            parent_data = {}
            child_files = {}

            # Split fields into parent and child
            for key, value in record.items():
                if isinstance(value, list):
                    # This is a nested array - save to a separate child file
                    child_file_name = f"record_{count}_{key}.json"
                    child_file_path = os.path.join(output_folder, child_file_name)

                    with open(child_file_path, 'w', encoding='utf-8') as child_file:
                        json.dump(value, child_file, indent=4)

                    child_files[key] = child_file_name  # Track the file name in parent data
                else:
                    # This is a simple field - keep it in the parent record
                    parent_data[key] = value

            # Add child file references to parent data
            parent_data['child_files'] = child_files

            # Write parent data with child file links
            parent_file_name = f"record_{count}_parent.json"
            parent_file_path = os.path.join(output_folder, parent_file_name)

            with open(parent_file_path, 'w', encoding='utf-8') as parent_file:
                json.dump(parent_data, parent_file, indent=4)

            print(f"Saved: {parent_file_path} with child files: {list(child_files.values())}")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl"  # Replace with your file path
    output_folder = r"C:\Users\munna\Downloads\parent_child_with_links_output"

    process_jsonl_to_parent_child_with_links(input_jsonl_path, output_folder)

    print(f"Processing complete. Files saved in '{output_folder}'.")
# Out:
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_1_parent.json with child files: ['record_1_articles.json', 'record_1_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_2_parent.json with child files: ['record_2_articles.json', 'record_2_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_3_parent.json with child files: ['record_3_articles.json', 'record_3_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_4_parent.json with child files: ['record_4_articles.json', 'record_4_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_5_parent.json with child files: ['record_5_articles.json', 'record_5_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_6_parent.json with child files: ['record_6_articles.json', 'record_6_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_7_parent.json with child files: ['record_7_articles.json', 'record_7_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_8_parent.json with child files: ['record_8_articles.json', 'record_8_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_9_parent.json with child files: ['record_9_articles.json', 'record_9_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_10_parent.json with child files: ['record_10_articles.json', 'record_10_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_11_parent.json with child files: ['record_11_articles.json', 'record_11_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_12_parent.json with child files: ['record_12_articles.json', 'record_12_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_13_parent.json with child files: ['record_13_articles.json', 'record_13_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_14_parent.json with child files: ['record_14_articles.json', 'record_14_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_15_parent.json with child files: ['record_15_articles.json', 'record_15_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_16_parent.json with child files: ['record_16_articles.json', 'record_16_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_17_parent.json with child files: ['record_17_articles.json', 'record_17_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_18_parent.json with child files: ['record_18_articles.json', 'record_18_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_19_parent.json with child files: ['record_19_articles.json', 'record_19_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_20_parent.json with child files: ['record_20_articles.json', 'record_20_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_21_parent.json with child files: ['record_21_articles.json', 'record_21_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_22_parent.json with child files: ['record_22_articles.json', 'record_22_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_23_parent.json with child files: ['record_23_articles.json', 'record_23_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_24_parent.json with child files: ['record_24_articles.json', 'record_24_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_25_parent.json with child files: ['record_25_articles.json', 'record_25_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_26_parent.json with child files: ['record_26_articles.json', 'record_26_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_27_parent.json with child files: ['record_27_articles.json', 'record_27_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_28_parent.json with child files: ['record_28_articles.json', 'record_28_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_29_parent.json with child files: ['record_29_articles.json', 'record_29_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_30_parent.json with child files: ['record_30_articles.json', 'record_30_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_31_parent.json with child files: ['record_31_articles.json', 'record_31_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_32_parent.json with child files: ['record_32_articles.json', 'record_32_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_33_parent.json with child files: ['record_33_articles.json', 'record_33_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record
handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_653_parent.json with child files: ['record_653_articles.json', 'record_653_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_654_parent.json with child files: ['record_654_articles.json', 'record_654_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_655_parent.json with child files: ['record_655_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_656_parent.json with child files: ['record_656_articles.json', 'record_656_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_657_parent.json with child files: ['record_657_articles.json', 'record_657_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_658_parent.json with child files: ['record_658_articles.json', 'record_658_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_659_parent.json with child files: ['record_659_articles.json', 'record_659_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_660_parent.json with child files: ['record_660_articles.json', 'record_660_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_661_parent.json with child files: ['record_661_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_662_parent.json with child files: ['record_662_articles.json', 'record_662_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_663_parent.json with child files: ['record_663_articles.json', 'record_663_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_664_parent.json with child files: ['record_664_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_665_parent.json with child files: ['record_665_articles.json', 'record_665_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_666_parent.json with child files: ['record_666_articles.json', 'record_666_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_667_parent.json with child files: ['record_667_articles.json', 'record_667_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_668_parent.json with child files: ['record_668_articles.json', 'record_668_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_669_parent.json with child files: ['record_669_articles.json', 'record_669_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_670_parent.json with child files: ['record_670_articles.json', 'record_670_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_671_parent.json with child files: ['record_671_articles.json', 'record_671_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_672_parent.json with child files: ['record_672_articles.json', 'record_672_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_673_parent.json with child files: ['record_673_articles.json', 'record_673_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_674_parent.json with child files: ['record_674_articles.json', 'record_674_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_675_parent.json with child files: ['record_675_articles.json', 'record_675_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_676_parent.json with child files: ['record_676_articles.json', 'record_676_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_677_parent.json with child files: ['record_677_articles.json', 'record_677_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_678_parent.json with child files: ['record_678_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_679_parent.json with child files: ['record_679_articles.json', 'record_679_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_680_parent.json with child files: ['record_680_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_681_parent.json with child files: ['record_681_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_682_parent.json with child files: ['record_682_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_683_parent.json with child files: ['record_683_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_684_parent.json with child files: ['record_684_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_685_parent.json with child files: ['record_685_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_686_parent.json with child files: ['record_686_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_687_parent.json with child files: ['record_687_handling_units.json']
# Saved: C:\Users\munna\Downloads\parent_child_with_links_output\record_688_parent.json with child files: ['record_688_handling_units.json']
# Processing complete. Files saved in 'C:\Users\munna\Downloads\parent_child_with_links_output'.

# %%
import json
import os

def extract_and_split_jsonl(input_jsonl_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        count = 0

        for line in file:
            count += 1
            record = json.loads(line)

            # Initialize files content
            basics_data = {}
            articles_data = []
            handling_units_data = []

            # Extract and split the data
            if 'basics' in record:
                basics_data = record['basics']

            if 'articles' in record:
                articles_data = record['articles']

            if 'handling_units' in record:
                handling_units_data = record['handling_units']

            # Write parent file (basics)
            basics_file = os.path.join(output_folder, f'record_{count}_basics.json')
            with open(basics_file, 'w', encoding='utf-8') as basics_out:
                json.dump(basics_data, basics_out, indent=4)

            # Write child file - articles
            articles_file = os.path.join(output_folder, f'record_{count}_articles.json')
            with open(articles_file, 'w', encoding='utf-8') as articles_out:
                json.dump(articles_data, articles_out, indent=4)

            # Write child file - handling units
            handling_units_file = os.path.join(output_folder, f'record_{count}_handling_units.json')
            with open(handling_units_file, 'w', encoding='utf-8') as handling_units_out:
                json.dump(handling_units_data, handling_units_out, indent=4)

            print(f"Processed Record {count}:")
            print(f"  - Basics saved to {basics_file}")
            print(f"  - Articles saved to {articles_file}")
            print(f"  - Handling Units saved to {handling_units_file}")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.json

#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_657_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_657_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_657_handling_units.json
# Processed Record 658:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_658_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_658_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_658_handling_units.json
# Processed Record 659:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_659_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_659_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_659_handling_units.json
# Processed Record 660:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_660_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_660_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_660_handling_units.json
# Processed Record 661:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_661_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_661_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_661_handling_units.json
# Processed Record 662:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_662_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_662_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_662_handling_units.json
# Processed Record 663:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_663_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_663_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_663_handling_units.json
# Processed Record 664:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_664_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_664_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_664_handling_units.json
# Processed Record 665:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_665_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_665_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_665_handling_units.json
# Processed Record 666:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_666_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_666_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_666_handling_units.json
# Processed Record 667:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_667_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_667_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_667_handling_units.json
# Processed Record 668:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_668_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_668_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_668_handling_units.json
# Processed Record 669:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_669_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_669_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_669_handling_units.json
# Processed Record 670:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_670_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_670_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_670_handling_units.json
# Processed Record 671:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_671_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_671_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_671_handling_units.json
# Processed Record 672:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_672_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_672_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_672_handling_units.json
# Processed Record 673:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_673_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_673_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_673_handling_units.json
# Processed Record 674:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_674_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_674_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_674_handling_units.json
# Processed Record 675:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_675_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_675_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_675_handling_units.json
# Processed Record 676:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_676_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_676_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_676_handling_units.json
# Processed Record 677:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_677_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_677_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_677_handling_units.json
# Processed Record 678:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_678_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_678_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_678_handling_units.json
# Processed Record 679:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_679_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_679_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_679_handling_units.json
# Processed Record 680:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_680_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_680_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_680_handling_units.json
# Processed Record 681:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_681_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_681_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_681_handling_units.json
# Processed Record 682:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_682_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_682_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_682_handling_units.json
# Processed Record 683:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_683_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_683_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_683_handling_units.json
# Processed Record 684:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_684_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_684_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_684_handling_units.json
# Processed Record 685:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_685_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_685_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_685_handling_units.json
# Processed Record 686:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_686_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_686_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_686_handling_units.json
# Processed Record 687:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_687_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_687_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_687_handling_units.json
# Processed Record 688:
#   - Basics saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_688_basics.json
#   - Articles saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_688_articles.json
#   - Handling Units saved to C:\Users\munna\Downloads\parent_child_three_files_output\record_688_handling_units.json
#
# ✅ Processing complete! All files are saved in 'C:\Users\munna\Downloads\parent_child_three_files_output'.

# %%
import json
import os
from collections.abc import MutableMapping

# Function to recursively flatten nested JSON
def flatten_json(nested_json, parent_key='', sep='_'):
    """Recursively flattens nested JSON object into a flat dictionary."""
    items = []
    if isinstance(nested_json, MutableMapping):
        for k, v in nested_json.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(flatten_json(v, new_key, sep=sep).items())
    elif isinstance(nested_json, list):
        # For lists, handle each item individually and store as separate flattened object
        for idx, item in enumerate(nested_json):
            items.extend(flatten_json(item, f"{parent_key}{sep}{idx}", sep=sep).items())
    else:
        items.append((parent_key, nested_json))
    return dict(items)

# Process and split all data into 3 combined files (main, articles, handling_units)
def process_and_combine_jsonl(input_jsonl_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    # Hold combined data
    all_main_records = []
    all_articles = []
    all_handling_units = []

    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        for line in file:
            record = json.loads(line)

            # Flatten top-level (main) record
            main_record = {}
            articles = record.get("articles", [])
            handling_units = record.get("handling_units", [])

            for key, value in record.items():
                if key not in ["articles", "handling_units"]:
                    if isinstance(value, dict):
                        flat_part = flatten_json(value, key)
                        main_record.update(flat_part)
                    else:
                        main_record[key] = value

            # Append to combined lists
            all_main_records.append(main_record)

            for article in articles:
                all_articles.append(flatten_json(article))

            for unit in handling_units:
                all_handling_units.append(flatten_json(unit))

    # Write combined outputs to files
    with open(os.path.join(output_folder, 'main.json'), 'w', encoding='utf-8') as main_file:
        json.dump(all_main_records, main_file, indent=4)

    with open(os.path.join(output_folder, 'rarticles.json'), 'w', encoding='utf-8') as articles_file:
        json.dump(all_articles, articles_file, indent=4)

    with open(os.path.join(output_folder, 'handling_units.json'), 'w', encoding='utf-8') as handling_units_file:
        json.dump(all_handling_units, handling_units_file, indent=4)

    print(f"✅ Process complete! All data saved into 3 files in '{output_folder}' folder.")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl"  # Update your path
    output_folder = r"C:\Users\munna\Downloads\flattened_outputs"

    process_and_combine_jsonl(input_jsonl_path, output_folder)

    print(f"✅ All flattened data saved to '{output_folder}' folder.")
# Out:
# ✅ Process complete! All data saved into 3 files in 'C:\Users\munna\Downloads\flattened_outputs' folder.
# ✅ All flattened data saved to 'C:\Users\munna\Downloads\flattened_outputs' folder.

# %%
import json
import os
from collections.abc import MutableMapping

# Function to recursively flatten nested JSON
def flatten_json(nested_json, parent_key='', sep='_'):
    """Recursively flattens nested JSON object into a flat dictionary."""
    items = []
    if isinstance(nested_json, MutableMapping):
        for k, v in nested_json.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(flatten_json(v, new_key, sep=sep).items())
    elif isinstance(nested_json, list):
        # Lists are not flattened at this stage (handled separately as children)
        items.append((parent_key, nested_json))
    else:
        items.append((parent_key, nested_json))
    return dict(items)

# Process JSONL file into parent and dynamic children
def process_jsonl_dynamically(input_jsonl_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    all_main_records = []
    all_children = {}

    # Read each line (record) in the JSONL
    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        for line in file:
            record = json.loads(line)

            main_record = {}
            record_children = {}

            # Split parent and child fields
            for key, value in record.items():
                if isinstance(value, list):
                    # Track this as a child array
                    if key not in all_children:
                        all_children[key] = []
                    record_children[key] = value
                elif isinstance(value, dict):
                    # Flatten nested dict into parent record
                    flat_dict = flatten_json(value, key)
                    main_record.update(flat_dict)
                else:
                    # Scalar values stay directly in the parent
                    main_record[key] = value

            # Append main record to main list
            all_main_records.append(main_record)

            # Append children into their respective global lists
            for child_name, child_list in record_children.items():
                for child_item in child_list:
                    # Optionally, you can add a reference key to link child to parent (like order_id if needed)
                    # Example: child_item['parent_id'] = main_record.get('transport_order_id', f'record_{len(all_main_records)}')
                    all_children[child_name].append(flatten_json(child_item))

    # Write main file
    main_file_path = os.path.join(output_folder, 'main.json')
    with open(main_file_path, 'w', encoding='utf-8') as main_file:
        json.dump(all_main_records, main_file, indent=4)

    # Write each child array to its own file
    for child_name, child_list in all_children.items():
        child_file_path = os.path.join(output_folder, f'{child_name}.json')
        with open(child_file_path, 'w', encoding='utf-8') as child_file:
            json.dump(child_list, child_file, indent=4)

    print(f"✅ Processing complete! Data saved to '{output_folder}'")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl"  # Change this path as needed
    output_folder = r"C:\Users\munna\Downloads\dynamic_flattened_output"

    process_jsonl_dynamically(input_jsonl_path, output_folder)

    print(f"✅ All data saved in '{output_folder}'.")
# Out:
# ✅ Processing complete! Data saved to 'C:\Users\munna\Downloads\dynamic_flattened_output'
# ✅ All data saved in 'C:\Users\munna\Downloads\dynamic_flattened_output'.

# %%
import json
import os
from collections.abc import MutableMapping

# Function to recursively flatten nested JSON
def flatten_json(nested_json, parent_key='', sep='_'):
    """Recursively flattens nested JSON object into a flat dictionary."""
    items = []
    if isinstance(nested_json, MutableMapping):
        for k, v in nested_json.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(flatten_json(v, new_key, sep=sep).items())
    elif isinstance(nested_json, list):
        # Lists are handled as children
        items.append((parent_key, nested_json))
    else:
        items.append((parent_key, nested_json))
    return dict(items)

# Function to detect primary object name (first non-list top-level key)
def detect_main_object_name(record):
    for key, value in record.items():
        if not isinstance(value, list):
            return key
    return "main"  # Fallback if all fields are lists (rare case)

# Process JSONL into parent and children, dynamically naming parent file
def process_jsonl_dynamically(input_jsonl_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    all_main_records = []
    all_children = {}

    # Detect main object name from the first record
    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        first_record = json.loads(file.readline())
        main_object_name = detect_main_object_name(first_record)

    # Process each record
    with open(input_jsonl_path, 'r', encoding='utf-8') as file:
        for line in file:
            record = json.loads(line)

            main_record = {}
            record_children = {}

            # Split parent (non-list) and children (list) fields
            for key, value in record.items():
                if isinstance(value, list):
                    if key not in all_children:
                        all_children[key] = []
                    record_children[key] = value
                elif isinstance(value, dict):
                    flat_dict = flatten_json(value, key)
                    main_record.update(flat_dict)
                else:
                    main_record[key] = value

            all_main_records.append(main_record)

            # Add children to global list
            for child_name, child_list in record_children.items():
                for child_item in child_list:
                    all_children[child_name].append(flatten_json(child_item))

    # Write dynamically named main file
    main_file_name = f"{main_object_name}.json"
    main_file_path = os.path.join(output_folder, main_file_name)
    with open(main_file_path, 'w', encoding='utf-8') as main_file:
        json.dump(all_main_records, main_file, indent=4)

    # Write each child array to its own file
    for child_name, child_list in all_children.items():
        child_file_path = os.path.join(output_folder, f'{child_name}.json')
        with open(child_file_path, 'w', encoding='utf-8') as child_file:
            json.dump(child_list, child_file, indent=4)

    print(f"✅ Processing complete! Parent data saved as '{main_file_name}' in '{output_folder}'")

# Example Usage
if __name__ == "__main__":
    input_jsonl_path = r"C:\Users\munna\Downloads\flat_t_os__items_1741258336.7634916_4b1a615482.jsonl"  # Update to actual path
    output_folder = r"C:\Users\munna\Downloads\dynamic_flattened_output"

    process_jsonl_dynamically(input_jsonl_path, output_folder)

    print(f"✅ All data saved to '{output_folder}'")
# Out:
# ✅ Processing complete! Parent data saved as 'basics.json' in 'C:\Users\munna\Downloads\dynamic_flattened_output'
# ✅ All data saved to 'C:\Users\munna\Downloads\dynamic_flattened_output'
